# %%
import diffeq as dq
dq.euler_step()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import diffeq as dq
# ----> 2 dq.euler_step()
#
# TypeError: euler_step() missing 4 required positional arguments: 'y', 'f', 't', and 'dt'
